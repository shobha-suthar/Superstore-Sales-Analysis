# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2a32b917-0aad-4bfd-872a-9da0b30b7edf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a32b917-0aad-4bfd-872a-9da0b30b7edf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_csv("superstore_final_dataset (1).csv", encoding="latin1")

# %%
df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub_Category',
#        'Product_Name', 'Sales'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 0          1  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156   8/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688   12/6/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608   12/1/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608   12/1/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608   12/1/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608   12/1/2016  17/01/2016  Standard Class
#
#      Customer_ID     Customer_Name    Segment        Country             City  \
# ...

# %% [markdown]
# # **how many missing values are present in each column**

# %%
df.isnull().sum()
# Out:
# Row_ID            0
# Order_ID          0
# Order_Date        0
# Ship_Date         0
# Ship_Mode         0
# Customer_ID       0
# Customer_Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal_Code      11
# Region            0
# Product_ID        0
# Category          0
# Sub_Category      0
# Product_Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# # **checks whether a complete row is repeated**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **helped us understand the numerical columns**

# %%
df.describe()
# Out:
#             Row_ID   Postal_Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %% [markdown]
# # **spot differences in spelling/capitalization**

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# # cleaning if there is actually a problem

# %%
df["Category"]=df["Category"].str.strip().str.title()

# %%
df["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df["Sub_Category"].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df["Ship_Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %% [markdown]
# # **make sure both dates are actually stored as dates**

# %%
df[["Order_Date","Ship_Date"]].dtypes
# Out:
# Order_Date    object
# Ship_Date     object
# dtype: object

# %% [markdown]
# # **currently treating these columns as text, not actual dates.**

# %%
df["Order_Date"]= pd.to_datetime(df["Order_Date"],dayfirst=True)

# %%
df["Ship_Date"] = pd.to_datetime(df["Ship_Date"], dayfirst=True)

# %% [markdown]
# # **doesn't contain negative zero**

# %%
(df["Sales"]<=0).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **order can contain multiple products**

# %%
df["Order_ID"].nunique()
# Out:
# 4922

# %%
df["Customer_ID"].nunique()
# Out:
# 793

# %%
df["Product_ID"].nunique()
# Out:
# 1861

# %%
df["State"].nunique()
# Out:
# 49

# %%
len(df)
# Out:
# 9800

# %% [markdown]
# # **check whether one Product_ID is linked to multiple Product_Names**

# %%
df.groupby("Product_ID")["Product_Name"].nunique().max()
# Out:
# 2

# %%
product_check= df.groupby("Product_ID")["Product_Name"].nunique()

# %%
product_check[product_check>1]
# Out:
# Product_ID
# FUR-BO-10002213    2
# FUR-CH-10001146    2
# FUR-FU-10001473    2
# FUR-FU-10004017    2
# FUR-FU-10004091    2
# FUR-FU-10004270    2
# FUR-FU-10004848    2
# FUR-FU-10004864    2
# OFF-AP-10000576    2
# OFF-AR-10001149    2
# OFF-BI-10002026    2
# OFF-BI-10004632    2
# OFF-BI-10004654    2
# OFF-PA-10000357    2
# OFF-PA-10000477    2
# OFF-PA-10000659    2
# OFF-PA-10001166    2
# OFF-PA-10001950    2
# OFF-PA-10001970    2
# OFF-PA-10002195    2
# OFF-PA-10002377    2
# OFF-PA-10003022    2
# OFF-ST-10001228    2
# OFF-ST-10004950    2
# TEC-AC-10002049    2
# TEC-AC-10002550    2
# TEC-AC-10003832    2
# TEC-MA-10001148    2
# TEC-PH-10001530    2
# TEC-PH-10001795    2
# TEC-PH-10002200    2
# TEC-PH-10002310    2
# TEC-PH-10004531    2
# Name: Product_Name, dtype: int64

# %%
df.groupby("Product_ID")["Product_Name"].nunique().value_counts()
# Out:
# Product_Name
# 1    1828
# 2      33
# Name: count, dtype: int64

# %% [markdown]
# # **need to know what time period our data covers**

# %%
df["Order_Date"].min(), df["Order_Date"].max()
# Out:
# (Timestamp('2015-01-03 00:00:00'), Timestamp('2018-12-30 00:00:00'))

# %%
df.columns.tolist()
# Out:
# ['Row_ID',
#  'Order_ID',
#  'Order_Date',
#  'Ship_Date',
#  'Ship_Mode',
#  'Customer_ID',
#  'Customer_Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal_Code',
#  'Region',
#  'Product_ID',
#  'Category',
#  'Sub_Category',
#  'Product_Name',
#  'Sales']

# %% [markdown]
# # **Total Revenue = Sum of Sales**

# %%
Total_sales=df["Sales"].sum()

# %%
Total_sales
# Out:
# np.float64(2261536.7827000003)

# %%
Total_orders=  df["Order_ID"].nunique()

# %%
Total_orders
# Out:
# 4922

# %% [markdown]
# # **AOV = Total Revenue ÷ Number of Orders**

# %%
Avg= Total_sales/Total_orders

# %%
Avg
# Out:
# np.float64(459.4751691791955)

# %%
round(Avg,2)
# Out:
# np.float64(459.48)

# %% [markdown]
# # **Sales by Region**

# %%
df.groupby("Region")["Sales"].sum()
# Out:
# Region
# Central    492646.9132
# East       669518.7260
# South      389151.4590
# West       710219.6845
# Name: Sales, dtype: float64

# %%
df.groupby("Region")["Sales"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# # **Sales by category
# # Technology = highest sales (827,455.87)
# # Furniture = lowest sales (728,658.58)

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          728658.5757
# Office Supplies    705422.3340
# Technology         827455.8730
# Name: Sales, dtype: float64

# %%
df.groupby("Category")["Sales"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# # **Sales over Time**

# %% [markdown]
# # **2018 highest total sales**

# %% [markdown]
# # **2016 lowest total sales**

# %%
df.groupby(df["Order_Date"].dt.year)["Sales"].sum()
# Out:
# Order_Date
# 2015    479856.2081
# 2016    459436.0054
# 2017    600192.5500
# 2018    722052.0192
# Name: Sales, dtype: float64

# %%
df.groupby(df["Order_Date"].dt.year)["Sales"].sum().plot(kind="line")
# Out:
# <Axes: xlabel='Order_Date'>

# %% [markdown]
# # **10 products have the highest total Sales?**

# %% [markdown]
# # **Canon imageCLASS 2200 Advanced Copier is your #1 product - total sales**

# %%
df.groupby("Product_Name")["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Product_Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24 Color                       18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
df.groupby("Product_Name")["Sales"].sum().sort_values(ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Name'>

# %% [markdown]
# # **High Speed Automatic Electric Letter Opener - lowest-selling product**

# %% [markdown]
# # **Bottom 10 Products**

# %%
df.groupby("Product_Name")["Sales"].sum().sort_values().tail(10)
# Out:
# Product_Name
# High Speed Automatic Electric Letter Opener                                    17030.312
# GBC DocuBind P400 Electric Binding System                                      17965.068
# HP Designjet T520 Inkjet Large Format Printer - 24 Color                       18374.895
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Name: Sales, dtype: float64

# %%
df.groupby("Product_Name")["Sales"].sum().sort_values().tail(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Name'>

# %% [markdown]
# # **Which month- highest total Sales?** November

# %% [markdown]
# # **month - lowest total sales?** february

# %%
df.groupby(df["Order_Date"].dt.month)["Sales"].sum().sort_values()
# Out:
# Order_Date
# 2      59371.1154
# 1      94291.6296
# 4     136283.0006
# 7     145535.6890
# 6     145837.5233
# 5     154086.7237
# 8     157315.9270
# 3     197573.5872
# 10    199496.2947
# 9     300103.4117
# 12    321480.1695
# 11    350161.7110
# Name: Sales, dtype: float64

# %%
df.groupby(df["Order_Date"].dt.month)["Sales"].sum().sort_values().plot(kind="line")
# Out:
# <Axes: xlabel='Order_Date'>

# %% [markdown]
# # Consumer has the highest sales
# # **Home Office has the lowest**

# %%
df.groupby("Segment")["Sales"].sum()
# Out:
# Segment
# Consumer       1.148061e+06
# Corporate      6.884941e+05
# Home Office    4.249822e+05
# Name: Sales, dtype: float64

# %% [markdown]
# # **Highest: Phones**
# # **Lowest**: Fasteners

# %%
df.groupby("Sub_Category")["Sales"].sum().sort_values()
# Out:
# Sub_Category
# Fasteners        3001.9600
# Labels          12347.7260
# Envelopes       16128.0460
# Art             26705.4100
# Supplies        46420.3080
# Paper           76828.3040
# Furnishings     89212.0180
# Appliances     104618.4030
# Bookcases      113813.1987
# Copiers        146248.0940
# Accessories    164186.7000
# Machines       189238.6310
# Binders        200028.7850
# Tables         202810.6280
# Storage        219343.3920
# Chairs         322822.7310
# Phones         327782.4480
# Name: Sales, dtype: float64

# %% [markdown]
# # **Top 5 Sub-Categories by Sales**

# %%
df.groupby("Sub_Category")["Sales"].sum().sort_values(ascending=False).head(5)
# Out:
# Sub_Category
# Phones     327782.448
# Chairs     322822.731
# Storage    219343.392
# Tables     202810.628
# Binders    200028.785
# Name: Sales, dtype: float64

# %%
df.to_csv("cleaned_superstore.csv", index=False)

# %%
from google.colab import files

# %%
files.download("cleaned_superstore.csv")

# %% [markdown]
# # **Key Insights**

# %% [markdown]
# - The West region generated the highest total sales.
# - Technology was the highest-selling category.
# - Consumer was the highest-selling customer segment.
# - 2018 had the highest total sales, while 2016 had the lowest.
# - November recorded the highest monthly sales, while February recorded the lowest.
# - Phones was the highest-selling sub-category.
# - High Speed Automatic Electric Letter Opener had the lowest total sales among the products analyzed.
